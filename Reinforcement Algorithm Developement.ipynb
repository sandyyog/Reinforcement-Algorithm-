# %%
import random
from typing import List

# %%
class Sampledata:
    def __init__(self):
        self.steps_left=25
    
    def get_observation(self) -> List[float]:
        return[0.0,0.0,0.0]
    
    def get_actions(self) ->List[int]:
        return[0,1]
    
    def is_done(self) -> bool:
        return self.steps_left==0
    
    def action(self,action:int):
        if self.is_done():
            raise Exception('Game is over')
        self.steps_left -=1
        return random.random()

# %%
class Agent:
    def __init__(self):
        self.total_reward=0.0
        
    def step(self,env:Sampledata):
        current_obs=env.get_observation()
        print('Observation {}'.format(current_obs))
        actions=env.get_actions()
        print(actions)
        reward=env.action(random.choice(actions))
        self.total_reward +=reward
        
        print('Total Reward {}'.format(self.total_reward))

# %%
if __name__=='__main__':
    env=Sampledata()
    agent=Agent()
    i=0
    while not env.is_done():
        i=i+1
        agent.step(env)
        print('Steps {}'.format(i))
        
        print('Total reward got:%0.5f'% agent.total_reward)
# Out:
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 0.7145494348292655
# Steps 1
# Total reward got:0.71455
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 1.2679400010738724
# Steps 2
# Total reward got:1.26794
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 1.577455197499127
# Steps 3
# Total reward got:1.57746
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 2.366238906967247
# Steps 4
# Total reward got:2.36624
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 2.7027966521848255
# Steps 5
# Total reward got:2.70280
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 3.4659895199562873
# Steps 6
# Total reward got:3.46599
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 4.274994992461416
# Steps 7
# Total reward got:4.27499
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 4.306777217324144
# Steps 8
# Total reward got:4.30678
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 4.535354531114054
# Steps 9
# Total reward got:4.53535
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 5.109988018502725
# Steps 10
# Total reward got:5.10999
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 5.673659725181319
# Steps 11
# Total reward got:5.67366
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 5.904827622709783
# Steps 12
# Total reward got:5.90483
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 6.321037990900438
# Steps 13
# Total reward got:6.32104
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 6.857109987050201
# Steps 14
# Total reward got:6.85711
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 7.4520281738847896
# Steps 15
# Total reward got:7.45203
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 7.517499604923169
# Steps 16
# Total reward got:7.51750
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 7.802948039479113
# Steps 17
# Total reward got:7.80295
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 8.44012971883205
# Steps 18
# Total reward got:8.44013
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 8.908877905688412
# Steps 19
# Total reward got:8.90888
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 9.134071482691272
# Steps 20
# Total reward got:9.13407
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 9.37704141092187
# Steps 21
# Total reward got:9.37704
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 9.99570194172347
# Steps 22
# Total reward got:9.99570
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 10.111642013979813
# Steps 23
# Total reward got:10.11164
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 10.40837698038864
# Steps 24
# Total reward got:10.40838
# Observation [0.0, 0.0, 0.0]
# [0, 1]
# Total Reward 10.710764553336332
# Steps 25
# Total reward got:10.71076
